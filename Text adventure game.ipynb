# %% [markdown]
# <hr style="height:3px;border:none;color:#333;background-color:#95D063;" />
# <strong>Game reference - Movie Shrek (2001)</strong>
#
# Avalable on Youtube, Amazon Prime Video, Apple TV, and more
# <hr style="height:3px;border:none;color:#333;background-color:#95D063;" />

# %%
################################################################
### import packages
################################################################

# if user did not originally install emoji package
# !pip install emoji
import time
import emoji
from sys import exit 
################################################################
### Game introduction and instruction
################################################################

# Welcome statement
print(emoji.emojize(f"""\033[1;30m

:sparkle: Welcome to Shrek simulation where you will be completing the story and win the game :sparkle:\n 
      
\033[1;30m{'-' * 85}\n
"""))

# warning message
print(emoji.emojize(f"""
                               \033[1;31m{'*' * 5} WARNING! {'*' * 5} \n
                                 
\033[1;30m:double_exclamation_mark: This may take a while to load and for your best experience, please play this game 
on a full screen. Thank you:double_exclamation_mark:

"""))
input(prompt = "<Press ENTER to continue>\n")

# story introduction
print(emoji.emojize(f"""
{'-' * 85}

Once upon a far far away, there was a giant green ogre named Shrek living in the 
middle of the wood feared by all people:deciduous_tree: Shrek enjoyed his private life in his 
lovely (kind of:thinking_face:) swamp until one day, things have changed. His land has been invaded 
by fairy tales creatures who have been banished by the order of Lord Faquaad, the 
'king' of Duloc:crown: Thus, by title, he is not yet there, so he has a mission to marry 
a princess, making Duloc a perfect kingdom:red_exclamation_mark: In this game, you'll help Shrek get 
through different tasks to get his perfect life back! Enjoy your journey!

{'-' * 85}
"""))
input(prompt = "<Press ENTER to continue>\n")

#room_1()

################################################################
### room_1: 3 questions 
################################################################

def room_1():
    
# question 1
    print(emoji.emojize(f"""
{'-' * 85}
:fleur-de-lis: WELCOME TO STAGE 1 :fleur-de-lis:

Just like another wonderful day as Shrek described. Suddenly, the fairy tales' 
creatures invaded Shrek's swamp to hide from Lord Faquaad's army, ruining his 
property:red_exclamation_mark: What should he do?

A) Tell them to get lost:angry_face:
B) Let them stay and teach them some manners:smiling_face_with_halo:


{'-' * 85}
"""))
    
    # defining object for while loop question 1
    chances = 2
    
    # while loop for user attemps question 1
    while chances > 0:
        choice = input(prompt = '<Press A or B to select your choice>').lower().split()
        
        # user choice 1 question 1 (true) - conditional statement based on user input
        if 'a' in choice or 'tell' in choice or 'one' in choice or 'get' in choice or 'lost' in choice:
            print(emoji.emojize(f"""\033[1;32m
They did not listen and continue to stay:face_with_rolling_eyes: Let's go settle things down with Lord Faquaad \n
\033[1;30m{'-' * 85} \n
"""))
            input(prompt = '<Press ENTER to continue>\n')
############# question 2
            print(emoji.emojize(f"""
{'-' * 85}

While Shrek is trying to get things sorted out, a fairy tale creature, a non-stop 
talking donkey:horse_face: wants to come along! Shrek is extremely annoyed, so he:

A) Try to scare Donkey away:smiling_face_with_horns: 
B) Try to run into the forest and hope Donkey cannot catch up:dashing_away: 

{'-' * 85}
"""))
            # define object for while loop question 2
            chances = 2
            
            # while loop for user attemps question 2
            while chances > 0:
                choice = input(prompt = '<Press A or B to select your choice>').lower().split()
                
                # user choice 1 question 2 (true) - conditional statement based on user input
                if 'a' in choice or 'scare' in choice or 'away' in choice:
                    print(emoji.emojize(f"""\033[1;32m
Donkey cannot comprehend and act as nothing happened:nerd_face: Now that we cannot do 
anything let's take Donkey along \n

\033[1;30m{'-' * 85} \n
"""))
                    input(prompt = '<Press ENTER to continue>\n')
##################### question 3
                    print(emoji.emojize(f"""
{'-' * 85}

Shrek and Donkey went to see Lord Faquaad to get the swamp back. However, Lord Faquaad 
disagrees:prohibited: After a long day of travel and lack of sleep, Shrek:

A) Kindly ask for his swamp back:pleading_face:
B) Choke Lord Faquaad 3 times:face_with_symbols_on_mouth: 

{'-' * 85}
"""))
                    # define object for while loop question 3
                    chances = 2
                    
                    # while loop for user attempt question 3
                    while chances > 0:
                        choice = input(prompt = '<Press A or B to select your choice>').lower().split()
                        
                        # user choice 1 question 3 (true) - conditional statement based on user input
                        if 'b' in choice or 'choke' in choice or 'lord' in choice or 'faquaad' in choice or '3' in choice or 'three' in choice or 'times' in choice:
                            
                            # declaring an object 
                            choke = 3
                            
                            # while loop for question 3 choice b
                            while choke > 0:
                                print(choke)
                                choke = choke - 1
                                
                                # time countdown
                                time.sleep(0.5)
                            print(emoji.emojize(f"""\033[1;31mHe still disagrees:thumbs_down: \n"""))
                            print(emoji.emojize(f"""\033[1;32m
As Shrek has no choice, he accept the deed and go on this dangerous adventure with 
his bestie, Donkey:crossed_swords: \n

\033[1;30m{'-' * 85} \n
"""))
                            input(prompt = '<Press ENTER to continue>\n')
                            room_2() # move to the next stage
                            # end while loop for question 3 choice b

                        # user choice 2 question 3 (false)
                        elif 'a' in choice or 'kindly' in choice or 'ask' in choice or 'swamp' in choice or 'back' in choice:
                            chances -= 1
                            
                            # nested condition of elif for question 3
                            if chances > 0:
                                print(emoji.emojize(f"""\033[1;31m
                            
Apparently, you're not important enough for him to care:person_tipping_hand:  

You have {chances} guesses remaining. \n 
\033[1;30m{'-' * 85} \n
"""))
                            elif chances == 0:
                                print(emoji.emojize(f"""\033[1;31m
You are out of guesses:frowning_face: \n
\033[1;30m{'-' * 85} \n                               
"""))
                                # user choice to exit or replay question 3
                                replay = input(prompt = '<Press A to start over or ANY key to exit>').lower().split()
                                
                                if 'a' in replay or 'start' in replay or 'over' in replay or 'replay' in replay:
                                    
                                    room_1() # replay
                                else:
                                    
                                    fail()
                                # end of user choice to exit or replay question 3 
                                
                            else:
                                print(emoji.emojize(':cross_mark:Error. Please try again:cross_mark:'))
                                
                                room_1() # replay
                            # end of nested condition question 3
                            
                        else:
                            print(emoji.emojize(f"""\033[1;31m
:cross_mark:Invalid input, please try again:cross_mark: \n
\033[1;30m{'-' * 85} \n
"""))
                            input(prompt = '<Press ENTER to try again>\n')
                            
                        # end of while loop attempt question 3
                    
                # user choice 2 question 2 (false)
                elif 'b' in choice or 'run' in choice or 'into' in choice or 'forest' in choice or 'hope' in choice or 'cannot' in choice or 'catch' in choice:
                    chances -= 1
                    
                    # nested condition of elif for question 2
                    if chances > 0:
                        print(emoji.emojize(f"""\033[1;31m
Unfortunately, Shrek did not take Track & Feild in high school so, Donkey caught up:pensive_face: 

You have {chances} guesses remaining. \n
\033[1;30m{'-' * 85}
"""))
                    elif chances == 0:
                        print(emoji.emojize(f"""\033[1;31m
You are out of guesses:frowning_face: \n
\033[1;30m{'-' * 85} \n                                
"""))
                        # user choice to exit or replay question 2
                        replay = input(prompt = '<Press A to start over or ANY key to exit>').lower().split()
                        
                        if 'a' in replay or 'start' in replay or 'over' in replay or 'replay' in replay:
                            
                            room_1() # replay
                            
                        else:
                            
                            fail()
                        # end of user choice to exit or replay question 2 
                        
                    else:
                        print(emoji.emojize(':cross_mark:Error. Please try again:cross_mark:'))
                        
                        room_1() # replay
                        # end of nested condition question 2   
            
                else:
                    print(emoji.emojize(f"""\033[1;31m
:cross_mark:Invalid input, please try again:cross_mark: \n
\033[1;30m{'-' * 85} \n
"""))
                    input(prompt = '<Press ENTER to try again>\n')
                    
            # end of while loop attempt question 2
        
        # user choice 2 question 1 (false)    
        elif 'b' in choice or 'two' in choice or 'let' in choice or 'stay' in choice or 'teach' in choice or 'manner' in choice or 'manners' in choice:
            chances -= 1
            
            # nested condition of elif for question 1
            if chances > 0:
                print(emoji.emojize(f""" \033[1;31m
Apparently, they do not care about your opinion and claim the swamp:confused_face:

You have {chances} guesses remaining. \n
\033[1;30m{'-' * 85} \n
"""))
            
            elif chances == 0:
                print(emoji.emojize(f"""\033[1;31m
You are out of guesses:frowning_face: \n
\033[1;30m{'-' * 85} \n                               
"""))
                # user choice to exit or replay question 1
                replay = input(prompt = '<Press A to start over or ANY key to exit>').lower().split()
                
                if 'a' in replay or 'start' in replay or 'over' in replay or 'replay' in replay:
                    
                    room_1() # replay
                    
                else:
                    
                    fail()
                # end of user choice to exit or replay question 1    
            
            else:
                print(emoji.emojize(':cross_mark:Error. Please try again:cross_mark:'))
                
                room_1() # replay
     
            # end of nested condition question 1    
                
        # user invalid input question 1        
        else:
            print(emoji.emojize(f""" \033[1;31m
:cross_mark:Invalid input, please try again:cross_mark: \n
\033[1;30m{'-' * 85} \n
"""))
            input(prompt = '<Press ENTER to try again>\n')
            
        # end of while loop attempt question 1
        

################################################################
### room_2
################################################################    
def room_2():
# question 1
    print(emoji.emojize(f"""
{'-' * 85}

:fleur-de-lis:YOU ARE NOW IN STAGE 2:fleur-de-lis:

Shrek and Donkey make their way to the tower. They need to cross a very shaky 
bridge that is at least 1000 years old with boiling lava under:volcano: What should he do?

A) Wait until the lava cools down to cross:hourglass_not_done:  
B) Get the courage and cross the bridge:flexed_biceps: 

{'-' * 85}
"""))
    
    # defining object for while loop question 1
    chances = 2
    
    # while loop for user attemps question 1
    while chances > 0:
        choice = input(prompt = '<Press A or B to select your choice>').lower().split()
        
        # user choice 1 question 1 (true) - conditional statement based on user input
        if 'b' in choice or 'courage' in choice or 'cross' in choice or 'bridge' in choice:
            print(emoji.emojize(f"""\033[1;32m
Whoaaa, that was tough, but you made it! High-five champ:hand_with_fingers_splayed: \n
\033[1;30m{'-' * 85} \n
"""))
            input(prompt = '<Press ENTER to continue>\n')
############# question 2
            print(emoji.emojize(f"""
{'-' * 85}

They made their entrance to the tower! Shrek and Donkey decided to separate to 
find Princess Fiona:princess:, but clumsy Donkey accidentally woke up the dragon:dragon_face:, 
and she's ready to burn them down! What should Shrek do? 
 
A) Use Donkey to distract the dragon and go rescue Princess Fiona:horse_face: 
B) Run, Shrek, run away!:dashing_away: 
{'-' * 85}
"""))
            # define object for while loop question 2
            chances = 2
            
            # while loop for user attemps question 2
            while chances > 0:
                choice = input(prompt = '<Press A or B to select your choice>').lower().split()
                
                # user choice 1 question 2 (true) - conditional statement based on user input
                if 'a' in choice or 'use' in choice or 'donkey' in choice or 'distract' in choice or 'dragon' in choice or 'rescue' in choice or 'princess' in choice or 'fiona' in choice:
                    print(emoji.emojize(f"""\033[1;32m
Teamwork makes dream works:star-struck: Now you got time to get the princess out of the tower! \n

\033[1;30m{'-' * 85} \n
"""))
                    input(prompt = '<Press ENTER to continue>\n')
##################### question 3
                    print(emoji.emojize(f"""
{'-' * 85}

Shrek found his way to the chamber that Princess Fiona was locked in. She was 
lying down, holding a flower on her bed peacefully:rose: How should Shrek approach 
to rescue her?

A) Kiss her to wake her up:kiss_mark:  
B) Pick her up and carry her out:raised_fist:  

{'-' * 85}
"""))
                    # define object for while loop question 3
                    chances = 2
                    
                    # while loop for user attempt question 3
                    while chances > 0:
                        choice = input(prompt = '<Press A or B to select your choice>').lower().split()
                        
                        # user choice 1 question 3 (true) - conditional statement based on user input
                        if 'b' in choice or 'pick' in choice or 'carry' in choice or 'out' in choice:
                            
                            print(emoji.emojize(f"""\033[1;32m
She's a little mad, but she assumes it's better than being stuck in the tower!:woman_shrugging: 

Good job! \n

\033[1;30m{'-' * 85} \n
"""))
                            input(prompt = '<Press ENTER to continue>\n')
                            room_3() # move to the next stage

                        # user choice 2 question 3 (false)
                        elif 'a' in choice or 'kiss' in choice or 'wake' in choice or 'wake up' in choice:
                            chances -= 1
                            
                            # nested condition of elif for question 3
                            if chances > 0:
                                print(emoji.emojize(f""" \033[1;31m
                            
This is not sleeping beauty, wrong plot:expressionless_face:

You have {chances} guesses remaining. \n
\033[1;30m{'-' * 85} \n
"""))
                            elif chances == 0:
                                print(emoji.emojize(f"""\033[1;31m
You are out of guesses:frowning_face: \n
\033[1;30m{'-' * 85} \n                                
"""))
                                # user choice to exit or replay question 3
                                replay = input(prompt = '<Press A to start over or ANY key to exit>').lower().split()
                                
                                if 'a' in replay or 'start' in replay or 'over' in replay or 'replay' in replay:
                                    
                                    room_2() # replay
                                else:
                                    
                                    fail()
                                # end of user choice to exit or replay question 3 
                                
                            else:
                                print(emoji.emojize(':cross_mark:Error. Please try again:cross_mark:'))
                                
                                room_2() # replay
                            # end of nested condition question 3
                            
                        else:
                            print(emoji.emojize(f"""\033[1;31m
:cross_mark:Invalid input, please try again:cross_mark: \n
\033[1;30m{'-' * 85} \n
"""))
                            input(prompt = '<Press ENTER to try again>\n')
                            
                        # end of while loop attempt question 3
                    
                # user choice 2 question 2 (false)
                elif 'b' in choice or 'run' in choice or 'away' in choice:
                    chances -= 1
                    
                    # nested condition of elif for question 2
                    if chances > 0:
                        print(emoji.emojize(f"""\033[1;31m
Shrek tripped and fell into the lava, bye-bye:fire: 

You have {chances} guesses remaining. \n
\033[1;30m{'-' * 85} \n
"""))
                    elif chances == 0:
                        print(emoji.emojize(f"""\033[1;31m
You are out of guesses:frowning_face: \n
\033[1;30m{'-' * 85} \n                                 
"""))
                        # user choice to exit or replay question 2
                        replay = input(prompt = '<Press A to start over or ANY key to exit>').lower().split()
                        
                        if 'a' in replay or 'start' in replay or 'over' in replay or 'replay' in replay:
                            
                            room_2() # replay
                            
                        else:
                            
                            fail()
                        # end of user choice to exit or replay question 2 
                        
                    else:
                        print(emoji.emojize(':cross_mark:Error. Please try again:cross_mark:'))
                        
                        room_2() # replay
                        # end of nested condition question 2   
            
                else:
                    print(emoji.emojize(f"""\033[1;31m
:cross_mark:Invalid input, please try again:cross_mark: \n
\033[1;30m{'-' * 85} \n
"""))
                    input(prompt = '<Press ENTER to try again>\n')
                    
            # end of while loop attempt question 2
        
        # user choice 2 question 1 (false)    
        elif 'a' in choice or 'wait' in choice or 'lava' in choice or 'cools' in choice or 'cool' in choice or 'down' in choice:
            chances -= 1
            
            # nested condition of elif for question 1
            if chances > 0:
                print(emoji.emojize(f"""\033[1;31m 
5 life rejuvenation later:alarm_clock: still hot! It looks like someone needs to take an 
additional science class!

You have {chances} guesses remaining. \n
\033[1;30m{'-' * 85} \n
"""))
            
            elif chances == 0:
                print(emoji.emojize(f"""\033[1;31m
You are out of guesses:frowning_face: \n
\033[1;30m{'-' * 85} \n                                
"""))
                # user choice to exit or replay question 1
                replay = input(prompt = '<Press A to start over or ANY key to exit>').lower().split()
                
                if 'a' in replay or 'start' in replay or 'over' in replay or 'replay' in replay:
                    
                    room_2() # replay
                    
                else:
                    
                    fail()
                # end of user choice to exit or replay question 1    
            
            else:
                print(emoji.emojize(':cross_mark:Error. Please try again:cross_mark:'))
                
                room_2() # replay
     
            # end of nested condition question 1    
        
        # user invalid input question 1        
        else:
            print(emoji.emojize(f"""\033[1;31m
:cross_mark:Invalid input, please try again:cross_mark: \n
\033[1;30m{'-' * 85} \n
"""))
            input(prompt = '<Press ENTER to try again>\n')
            
        # end of while loop attempt question 1

################################################################
### room_3
################################################################
def room_3():
# question 1
    print(emoji.emojize(f"""
{'-' * 85}

:fleur-de-lis:WELCOME TO THE FINAL STAGE:fleur-de-lis:

You rescue Princess Fiona, and somehow, Donkey calms the dragon down! Now Donkey 
got a new girlfriend (the dragon is a female:winking_face:) and Shrek and Fiona fall 
in love :red_heart: What should Shrek do?

A) Confess to Princess Fiona:smiling_face_with_heart-eyes:  
B) Ignore it, bring Fiona back to Lord Faquaad and get the swamp back:thumbs_down:


{'-' * 85}
"""))
    
    # defining object for while loop question 1
    chances = 2
    
    # while loop for user attemps question 1
    while chances > 0:
        choice = input(prompt = '<Press A or B to select your choice>').lower().split()
        
        # user choice 1 question 1 (true) - conditional statement based on user input
        if 'a' in choice or 'confess' in choice or 'tell' in choice or 'love' in choice:
            print(emoji.emojize(f"""\033[1;32m
Turn out she felt the same, so now Shrek and Princess Fiona try to escape together:revolving_hearts: \n
\033[1;30m{'-' * 85} \n
"""))
            input(prompt = '<Press ENTER to continue>\n')
############# question 2
            print(emoji.emojize(f"""
{'-' * 85}

Before Shrek and Fiona got away, Lord Faquaad found them and kidnaps Princess Fiona 
back to marry him:woman_with_veil:, so Shrek:
 
A) Go back to the swamp, eat ice cream while binge-watching Netflix, and cry:shaved_ice::television::loudly_crying_face:
B) Attempt to rescue Princess Fiona back:man_superhero:
 
{'-' * 85}
"""))
            # define object for while loop question 2
            chances = 2
            
            # while loop for user attemps question 2
            while chances > 0:
                choice = input(prompt = '<Press A or B to select your choice>').lower().split()
                
                # user choice 1 question 2 (true) - conditional statement based on user input
                if 'b' in choice or 'attempt' in choice or 'rescue' in choice or 'princess' in choice or 'fiona' in choice:
                    print(emoji.emojize(f"""\033[1;32m
That's the courage! Shrek, Donkey, and his girlfriend crashed the wedding:smiling_face_with_sunglasses: \n

\033[1;30m{'-' * 85} \n
"""))
                    input(prompt = '<Press ENTER to continue>\n')
                    win()
                    
##################### WIN!!!
    
                # user choice 2 question 2 (false)
                elif 'a' in choice or 'back' in choice or 'swamp' in choice or 'eat' in choice or 'ice' in choice or 'cream' in choice or 'binge' in choice or 'watch' in choice or 'watching' in choice or 'netflix' in choice:
                    chances -= 1
                    
                    # nested condition of elif for question 2
                    if chances > 0:
                        print(emoji.emojize(f"""\033[1;31m
The fairy tale creatures are still there, and they ate his ice cream as well. Now 
he ended up with uninvited creatures and no ice cream:pensive_face: 

You have {chances} guesses remaining. \n
\033[1;30m{'-' * 85} \n
"""))
                    elif chances == 0:
                        print(emoji.emojize(f"""\033[1;31m
You are out of guesses:frowning_face: \n
\033[1;30m{'-' * 85} \n                               
"""))
                        # user choice to exit or replay question 2
                        replay = input(prompt = '<Press A to start over or ANY key to exit>').lower().split()
                        
                        if 'a' in replay or 'start' in replay or 'over' in replay or 'replay' in replay:
                            
                            room_3() # replay 
                            
                        else:
                            
                            fail()
                        # end of user choice to exit or replay question 2 
                        
                    else:
                        print(emoji.emojize(':cross_mark:Error. Please try again:cross_mark:'))
                        
                        room_3() # replay
                        # end of nested condition question 2   
            
                else:
                    print(emoji.emojize(f"""\033[1;31m
:cross_mark:Invalid input, please try again:cross_mark: \n
\033[1;30m{'-' * 85} \n
"""))
                    input(prompt = '<Press ENTER to try again>\n')
                    
            # end of while loop attempt question 2
        
        # user choice 2 question 1 (false)    
        elif 'b' in choice or 'ignore' in choice or 'bring' in choice or 'back' in choice or 'lord' in choice or 'faquaad' in choice or 'swamp' in choice:
            chances -= 1
            
            # nested condition of elif for question 1
            if chances > 0:
                print(emoji.emojize(f"""\033[1;31m
You got your swamp back, grow old and die alone:coffin: That's sad

You have {chances} guesses remaining. \n
\033[1;30m{'-' * 85} \n
"""))
            
            elif chances == 0:
                print(emoji.emojize(f"""\033[1;31m
You are out of guesses:frowning_face: \n
\033[1;30m{'-' * 85} \n                                
"""))
                # user choice to exit or replay question 1
                replay = input(prompt = '<Press A to start over or ANY key to exit>').lower().split()
                
                if 'a' in replay or 'start' in replay or 'over' in replay or 'replay' in replay:
                    
                    room_3() # replay
                    
                else:
                    
                    fail()
                # end of user choice to exit or replay question 1    
            
            else:
                print(emoji.emojize(':cross_mark:Error. Please try again:cross_mark:'))
                
                room_3() # replay
     
            # end of nested condition question 1    
        
        # user invalid input question 1        
        else:
            print(emoji.emojize(f"""\033[1;31m
:cross_mark:Invalid input, please try again:cross_mark: \n
\033[1;30m{'-' * 85} \n
"""))
            input(prompt = '<Press ENTER to try again>\n')
            
        # end of while loop attempt question 1
        
################################################################
### win
################################################################

def win():
# print winning message
    print(emoji.emojize(f"""
{'-' * 85}
\033[1;32m
      ____                            _         _       _   _             
     / ___|___  _ __   __ _ _ __ __ _| |_ _   _| | __ _| |_(_) ___  _ __  
    | |   / _ \| '_ \ / _` | '__/ _` | __| | | | |/ _` | __| |/ _ \| '_ \ 
    | |__| (_) | | | | (_| | | | (_| | |_| |_| | | (_| | |_| | (_) | | | |
     \____\___/|_| |_|\__, |_|  \__,_|\__|\__,_|_|\__,_|\__|_|\___/|_| |_|
                      |___/                                               
\n
\033[1;30m
Shrek and the gang crashed the wedding:grinning_squinting_face: Shrek finally got Princess Fiona back 
and banished Lord Faquaad out of the kingdom! They are now planning to get 
married and live happily ever after:partying_face::party_popper:

{'-' * 85} \n
"""))
    input(prompt = '<Press ENTER to continue>\n')
    # bonus for winner
    print(emoji.emojize(f"""
                               \033[1;31m{'*' * 5} BONUS! {'*' * 5}\n
\033[1;30m
Before we end this, let's make this ending less boring! Like any great movie, there's 
always a good music! Choose your ending music or simply press ANY key to exit.

A) I'm a Believer - Smash Mouth:musical_note:
B) All Star - Smash Mouth:musical_note:
C) I don’t know these songs:frowning_face:
D) Exit the game:waving_hand:

P.S. If you don't know these songs, you automatically failed the game:pouting_face: 
Press ENTER to exit and go watch Shrek! 

{'-' * 85} \n
"""))
    # user choice for music
    choice = input(prompt = '<Select your option>').lower().split()
    
    # user choice for music - conditional statement
    if 'a' in choice or '1' in choice or 'beliver' in choice:
        print(emoji.emojize(f"""\033[1;32m
{':musical_notes:' * 30}

Then I saw her face, now I'm a believer
Not a trace, of doubt in my mind

{':musical_notes:' * 30}

Thank you for playing:beaming_face_with_smiling_eyes:! \n

\033[1;30m{'-' * 85} \n
"""))
        input(prompt = '<Press ENTER to exit>\n')
        exit(0) # exit game
    # user music choice 2    
    elif 'b' in choice or '2' in choice or 'all' in choice or 'star' in choice:
        print(emoji.emojize(f"""\033[1;32m
{':musical_notes:' * 30}

Hey now, you're an all-star, get your game on, go play
Hey now, you're a rock star, get the show on, get paid
And all that glitters is gold
Only shooting stars break the mold

{':musical_notes:' * 30}

Thank you for playing:beaming_face_with_smiling_eyes:! \n

\033[1;30m{'-' * 85} \n
"""))
        input(prompt = '<Press ENTER to exit>\n')
        exit(0) # exit game
    # user music choice 3    
    elif 'c' in choice or '3' in choice or 'don' in choice or 'know' in choice:
        fail() # fail 
    # user music choice 4    
    else:
        print(emoji.emojize(f"""
Thank you for playing!:beaming_face_with_smiling_eyes:

{'-' * 85}
"""))
        input(prompt = '<Press any key to exit>\n')
        exit(0) # exit game
    # end of conditional statement
        
################################################################
### fail
################################################################

def fail():
# print message for failing
    print(emoji.emojize(f"""\033[1;31m
                 ___  ___  _ __ _ __ _   _ 
                / __|/ _ \| '__| '__| | | |
                \__ \ (_) | |  | |  | |_| |
                |___/\___/|_|  |_|   \__, |
                                      __/ |
                                     |___/ 
\n
\033[1;30m
You've failed, but thank you for playing!:beaming_face_with_smiling_eyes:

{'-' * 85} \n
"""))
    input(prompt = '<Press any key to exit>\n')

room_1() # EVERYTHING goes before this clause

# game end
# Out:
# ❇️ Welcome to Shrek simulation where you will be completing the story and win the game ❇️
#
#
# -------------------------------------------------------------------------------------
#
#
#
#                                ***** WARNING! *****
#
#
# ‼️ This may take a while to load and for your best experience, please play this game
# on a full screen. Thank you‼️
#
#
# <Press ENTER to continue>
#
#
# -------------------------------------------------------------------------------------
#
# Once upon a far far away, there was a giant green ogre named Shrek living in the
# middle of the wood feared by all people🌳 Shrek enjoyed his private life in his
# lovely (kind of🤔) swamp until one day, things have changed. His land has been invaded
# by fairy tales creatures who have been banished by the order of Lord Faquaad, the
# 'king' of Duloc👑 Thus, by title, he is not yet there, so he has a mission to marry
# a princess, making Duloc a perfect kingdom❗ In this game, you'll help Shrek get
# ...
